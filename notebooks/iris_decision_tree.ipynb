# %%
from sklearn import tree
from sklearn.model_selection  import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
import numpy as np
import pandas as pd
df = pd.read_csv("https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv")
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
numeration = {'Versicolor ': 1,'Virginica ': 2,'Setosa': 3}
df['variety'] = df['variety'].replace(numeration)
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2       3
# 1           4.9          3.0           1.4          0.2       3
# 2           4.7          3.2           1.3          0.2       3
# 3           4.6          3.1           1.5          0.2       3
# 4           5.0          3.6           1.4          0.2       3

# %%
X_train, X_test, y_train, y_test = train_test_split(df[:3], df['variety'], test_size = 0.3, random_state = 42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(df[:3], df['variety'], test_size = 0.3, random_state = 42)
#
# File ~\Documents\TC2004B\tc2004b_env\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\Documents\TC2004B\tc2004b_env\Lib\site-packages\sklearn\model_selection\_split.py:2921, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2918 if n_arrays == 0:
#    2919     raise ValueError("At least one array required as input")
# -> 2921 arrays = indexable(*arrays)
#    2923 n_samples = _num_samples(arrays[0])
#    2924 n_train, n_test = _validate_shuffle_split(
#    2925     n_samples, test_size, train_size, default_test_size=0.25
#    2926 )
#
# File ~\Documents\TC2004B\tc2004b_env\Lib\site-packages\sklearn\utils\validation.py:521, in indexable(*iterables)
#     491 """Make arrays indexable for cross-validation.
#     492
#     493 Checks consistent length, passes through None, and ensures that everything
#    (...)    517 [[1, 2, 3], array([2, 3, 4]), None, <...Sparse...dtype 'int64'...shape (3, 1)>]
#     518 """
#     520 result = [_make_indexable(X) for X in iterables]
# --> 521 check_consistent_length(*result)
#     522 return result
#
# File ~\Documents\TC2004B\tc2004b_env\Lib\site-packages\sklearn\utils\validation.py:464, in check_consistent_length(*arrays)
#     462 lengths = [_num_samples(X) for X in arrays if X is not None]
#     463 if len(set(lengths)) > 1:
# --> 464     raise ValueError(
#     465         "Found input variables with inconsistent numbers of samples: %r"
#     466         % [int(l) for l in lengths]
#     467     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [3, 150]
